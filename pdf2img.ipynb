# %%
import easyocr
reader = easyocr.Reader(['ch_sim','en']) # this needs to run only once to load the model into memory
result = reader.readtext('page0.jpg')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
for r in result:
    print(r[1])
    print(r[0])
# Out:
# Innovation in Database Management: Computer Science
# [[219, 162], [1562, 162], [1562, 230], [219, 230]]
# VS
# [[710, 242], [768, 242], [768, 274], [710, 274]]
# Engineering
# [[790, 224], [1085, 224], [1085, 289], [790, 289]]
# Kenneth R。 Jacobs
# [[755, 365], [1033, 365], [1033, 403], [755, 403]]
# Vice President Product Strategy
# [[658, 402], [1129, 402], [1129, 452], [658, 452]]
# Oracle8 Program Manager
# [[700, 442], [1086, 442], [1086, 492], [700, 492]]
# Server Technologies Division
# [[686, 482], [1099, 482], [1099, 525], [686, 525]]
# kjacobs@oracle.com
# [[747, 523], [1037, 523], [1037, 563], [747, 563]]
# Oracle Corporation
# [[771, 590], [1015, 590], [1015, 631], [771, 631]]
# 400 Oracle Parkway
# [[767, 624], [1018, 624], [1018, 663], [767, 663]]
# Redwood Shores, CA 94065
# [[722, 659], [1062, 659], [1062, 692], [722, 692]]
# tivities surrounding the release of Oracle's next gen-
# [[911, 781], [1565, 781], [1565, 823], [911, 823]]
# ...

# %%
a = [""*6]

print(a)
# Out:
# ['']
